# %% [markdown]
# # import numpy as np
# # import pandas as pd
# # Importing Python Libaries

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns %matplotlib inline

# %% [markdown]
# # Loading Loan Data Frame Head

# %%
Loan=pd.read_csv("loan.csv", low_memory=False)

# %%
Loan.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %% [markdown]
# # Loan Data Frame Columns

# %%
loan.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6256/117342159.py in <module>
# ----> 1 loan.columns
#
# NameError: name 'loan' is not defined

# %% [markdown]
# # Cleaning the Loan Data Frame unessential data columns

# %%
to_drop = ['num_tl_90g_dpd_24m',
           'num_tl_op_past_12m',
           'pct_tl_nvr_dlq',
           'percent_bc_gt_75',
           'pub_rec_bankruptcies',
           'tax_liens','tot_hi_cred_lim',
           'total_bal_ex_mort',
           'total_bc_limit',
           'total_il_high_credit_limit',
           'num_actv_rev_tl',
           'num_bc_sats',
           'num_bc_tl',
           'num_il_tl',
           'num_op_rev_tl'
           'num_rev_accts',
           'num_rev_tl_bal_gt_0',
           'num_sats',
           'num_tl_120dpd_2m',
           'num_tl_30dpd',
           'num_tl_90g_dpd_24m',
           'num_tl_op_past_12m',
           'pct_tl_nvr_dlq',
           'percent_bc_gt_75',
           'pub_rec_bankruptcies',
           'tax_liens',
           'tot_hi_cred_lim',
           'tot_hi_cred_lim',
           'total_bal_ex_mort',
           'total_bc_limit',
           'total_il_high_credit_limit',
           'num_op_rev_tlnum_rev_accts',
           'pub_rec_bankruptciestax_liens']

# %%
Loan.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %% [markdown]
# # Loading Loan Data Frame Tail

# %%
Loan.tail()
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 39712  92187      92174       2500         2500           1075.0   36 months
# 39713  90665      90607       8500         8500            875.0   36 months
# 39714  90395      90390       5000         5000           1325.0   36 months
# 39715  90376      89243       5000         5000            650.0   36 months
# 39716  87023      86999       7500         7500            800.0   36 months
#
#       int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 39712    8.07%        78.42     A        A4  ...                NaN
# 39713   10.28%       275.38     C        C1  ...                NaN
# 39714    8.07%       156.84     A        A4  ...                NaN
# 39715    7.43%       155.38     A        A2  ...                NaN
# 39716   13.75%       255.43     E        E2  ...                NaN
#
#       num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75  \
# ...

# %% [markdown]
# # Showing Full Loan Data Frame without Cleaning

# %%
Loan
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  ...  \
# 0       36 months   10.65%       162.87     B        B2  ...
# ...

# %% [markdown]
# # High Level Statistics of Loan Data Frame

# %%
print(Loan.describe())
print("*"*60)
print(Loan.info())
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %% [markdown]
# # Creating Shape of Loan Data Frame as per given data

# %%
Loan.shape
# Out:
# (39717, 111)

# %% [markdown]
# # Creating a plot of Loan Data Frame

# %%
import matplotlib.pyplot
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])

loan_amnt=Loan.loan_amnt > 5000
ax.pie(Loan.id,labels=Loan.id)
plt.show()

# %% [markdown]
# # Reading Field Names and Records as per csv in loan Data Frame

# %%
import csv
file = open("Loan.csv")
csvreader = csv.reader(file)
header = next(csvreader)
print(header)
rows = []
for row in csvreader:
    rows.append(row)
print(rows)
file.close()
# Out:
# ['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'annual_inc', 'verification_status', 'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose', 'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d', 'collections_12_mths_ex_med', 'mths_since_last_major_derog', 'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_il_6m', 'open_il_12m', 'open_
# ...

# %% [markdown]
# # Loan Data Frame All columns

# %%
import pandas as pd
Loan= pd.read_csv("Loan.csv")
Loan.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens',
#        'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit'],
#       dtype='object', length=111)

# %% [markdown]
# # Bivariate Analysis
# # Scatter Plot

# %%
df  = pd.read_csv("Loan.csv",low_memory=False)
df.plot(x='id', y='loan_amnt', kind='scatter')
plt.show()

# %% [markdown]
# # Boxplot

# %%
import pandas as pd
df  = pd.read_csv("Loan.csv",low_memory=False)
df.boxplot(column='member_id', by='loan_amnt')
plt.show()

# %% [markdown]
# # Barplot

# %%
import pandas as pd
df  = pd.read_csv("Loan.csv",low_memory=False)
counts = df['member_id'].value_counts()
counts.plot(kind='bar')
plt.show()

# %% [markdown]
# # Univariate Analysis

# %%
import pandas as pd
reviews = pd.read_csv("Loan.csv", index_col=0)
reviews.head(3)
reviews['funded_amnt'].value_counts().head(10).plot.bar()

# %% [markdown]
# # Univariate Data Visualizations

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd
df  = pd.read_csv("Loan.csv",low_memory=False)
plt.scatter(df.index,df['sepal.width'])
plt.show()

# %% [markdown]
# # Loan Data transfer to Notepad

# %%
import csv
filename = 'Loan.csv'
with open(filename, 'w', newline="") as file:
    csvwriter = csv.writer(file) # 2. create a csvwriter object
    csvwriter.writerow(header) # 4. write the header
    csvwriter.writerows(data) # 5. write the rest of the data

header = ['id', 'member_id', 'loan_amnt']
data = [[1077501, 1296599, 5000], [1077430, 1314167, 2500], [1077175, 1313524, 2400]]
filename = 'Loan.csv'
with open(filename, 'w') as file:
    for header in header:
        file.write(str(header)+', ')
    file.write('n')
    for row in data:
        for x in row:
            file.write(str(x)+', ')
        file.write('n')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6256/1616441031.py in <module>
#       1 import csv
#       2 filename = 'Loan.csv'
# ----> 3 with open(filename, 'w', newline="") as file:
#       4     csvwriter = csv.writer(file) # 2. create a csvwriter object
#       5     csvwriter.writerow(header) # 4. write the header
#
# PermissionError: [Errno 13] Permission denied: 'Loan.csv'

# %%
import pandas as pd
import matplotlib.pyplot as plt
df  = pd.read_csv("Loan.csv",low_memory=False)
df.plot()  # plots all columns against index
df.plot(kind='scatter',x='member_id',y='loan_amnt') # scatter plot
df.plot(kind='density')  # estimate density function
# df.plot(kind='hist')  # histogram
